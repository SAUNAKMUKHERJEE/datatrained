# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# So there are 30 rows and 17 columns are present

# %% [markdown]
# # Checking null values:

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # so there is no null values are present

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df["W"].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
df.loc[df['W']==" "]
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, RA, ER, ERA, CG, SHO, SV, E]
# Index: []

# %% [markdown]
# # EDA

# %% [markdown]
# visualization of data

# %%
sns.pairplot(df)

# %% [markdown]
# # Observation

# %% [markdown]
# data is scattered

# %% [markdown]
# # Scatter plot

# %%
sns.scatterplot(x="R",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
sns.scatterplot(x="AB",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
sns.scatterplot(x="H",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.scatterplot(x="2B",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
sns.scatterplot(x="3B",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
sns.scatterplot(x="HR",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %%
sns.scatterplot(x="BB",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %%
sns.scatterplot(x="SO",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %%
sns.scatterplot(x="SB",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %%
sns.scatterplot(x="RA",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %%
sns.scatterplot(x="ER",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
sns.scatterplot(x="ERA",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %%
sns.scatterplot(x="CG",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %%
sns.scatterplot(x="SHO",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %%
sns.scatterplot(x="SV",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %%
sns.scatterplot(x="E",y="W",data=df)
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %% [markdown]
# # Correlation:

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor="blue",fmt='2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # CORRELATION OBSEVATION

# %% [markdown]
#  HERE "ER",'ERA','3B' AND "RA" THEY ARE VERY NAGETIVLY CORRELATED TO EACH OTHER

# %% [markdown]
# sv,sho,2B,HR,R this are strongly correlated

# %% [markdown]
# H, SO,CG this are weakly correlated

# %% [markdown]
# # VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x=df.iloc[:,0:-1]
x
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
x.shape
# Out:
# (30, 16)

# %%
x.shape[1]
# Out:
# 16

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      88
# 1      86
# 2      79
# 3     101
# 4      86
# 5      88
# 6      93
# 7      77
# 8      95
# 9      97
# 10    119
# 11     85
# 12     93
# 13     94
# 14    126
# 15     96
# 16    122
# 17    111
# 18    116
# 19     90
# 20     88
# 21     90
# 22     77
# 23     90
# 24    117
# 25     75
# 26     78
# 27     86
# 28     92
# 29     95
# Name: E, dtype: int64

# %%
def calc_vif():
    vif=pd.DataFrame()
    vif["variables"]=x.columns
    vif["VIF FACTOR"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    print(vif)

# %%
calc_vif()
# Out:
#    variables    VIF FACTOR
# 0          W   1131.592081
# 1          R   2729.223483
# 2         AB   4587.656163
# 3          H   3944.256949
# 4         2B   1148.244299
# 5         3B     32.165879
# 6         HR    261.646557
# 7         BB    276.696044
# 8         SO    394.508557
# 9         SB     28.235935
# 10        RA  17276.774405
# 11        ER  50628.792861
# 12       ERA  21316.455066
# 13        CG     10.029250
# 14       SHO     32.291567
# 15        SV    316.473282

# %% [markdown]
# here  we can see high VIF factor on ER

# %%
df=df.drop(["ER"],axis=1)
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ERA  CG  SHO  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  3.73   2    8
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  4.07   2   12
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  3.67  11   10
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  3.98   7    9
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  4.64   7   12
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  3.80   7   10
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  4.03   3    4
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  4.05   0   10
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  3.74   1   12
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  4.31   3   10
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  4.24   5    9
# ...

# %% [markdown]
# # DESCRIBING

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12) 
plt.show()

# %% [markdown]
# W
#
# mean:80
#
# median:81
#
# min:63
#
# Max: 100

# %% [markdown]
# AB
#
# mean:688
#
# median:5510
#
# min:1336
#
# Max: 5649

# %% [markdown]
# H
#
# mean:1403
#
# median:1382
#
# min:236
#
# Max: 1515

# %% [markdown]
# 2B
#
# mean:274
#
# median:262
#
# min:236
#
# Max: 308

# %%
3B

mean:163

median:153

min:31

Max: 233

# %% [markdown]
# HR
#
# mean:163
#
# median:158
#
# min:100
#
# Max: 232

# %% [markdown]
# BB
#
# mean:469
#
# median:473
#
# min:375
#
# Max: 570

# %% [markdown]
# SO
#
# mean:1248
#
# median:1261
#
# min:973
#
# Max: 1518

# %% [markdown]
# SB
#
# mean:83
#
# median:83
#
# min:44
#
# Max: 134

# %% [markdown]
# RA
#
# mean:688
#
# median:695
#
# min:525
#
# Max: 844

# %% [markdown]
# ERA
#
# mean:3.9
#
# median:4.02
#
# min:2.94
#
# Max: 5.04

# %% [markdown]
# CG
#
# mean:3.4
#
# median:3
#
# min:0
#
# Max: 11

# %% [markdown]
# SV
#
# mean:43
#
# median:42
#
# min:28
#
# Max: 62

# %% [markdown]
# E
#
# mean:94
#
# median:91
#
# min:75
#
# Max: 126

# %% [markdown]
# # Let's plot Distribution curve

# %%
from sklearn.preprocessing import LabelEncoder
for column in df:
    if df[column].dtypes == 'object':
        encoder = LabelEncoder()
        df[column] = encoder.fit_transform(df[column])

# %% [markdown]
# Box plot

# %%
colist=df.columns.values
graph=1
plt.figure(figsize=(10,10))
for i in range(0, len(colist)):
    plt.subplot(2,9,graph)
    sns.boxplot(df[colist[i]],color='green',orient='h')
    graph+=1
    plt.tight_layout()

# %% [markdown]
# WE HAVE SEEN SOME OUTLAYERS ARE PRESENT

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df['R'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Some oulayers are present

# %%
df['AB'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['H'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['2B'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['3B'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['HR'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['BB'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SO'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SB'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['RA'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['ERA'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# some outlayers are present

# %%
df['CG'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SHO'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# some outlayers are present

# %%
df['SV'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# somee outlayers are present

# %%
df['E'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# some outlayers are present

# %% [markdown]
# # Outlayer Removing

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (30, 17)

# %%
threshold=3 #rule of thumb
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 1

# %%
z.iloc[5]
# Out:
# W      1.170814
# R      3.509647
# AB     0.104884
# H      1.361089
# 2B     1.869832
# 3B     1.391501
# HR     2.185047
# BB     1.798742
# SO     0.952796
# SB     0.200609
# RA     0.257184
# ER     0.389104
# ERA    0.350165
# CG     1.300442
# SHO    0.320914
# SV     1.171848
# E      0.461470
# Name: 5, dtype: float64

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
df_new_z.shape
# Out:
# (29, 17)

# %% [markdown]
# # Data loss percentage

# %%
(30-29)/30*100
# Out:
# 3.3333333333333335

# %% [markdown]
# # 3.33% data have been removed

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
x=df_new_z.iloc[:,:-1]
#target
y=df_new_z.iloc[:,-1]

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 1.38207890e+00,  9.62543504e-01,  0.00000000e+00,
#          0.00000000e+00,  1.68518793e+00,  1.00615029e+00,
#         -7.41927000e-01, -1.60519802e+00, -2.55061247e+00,
#          9.36131648e-01, -6.60978697e-01, -5.08052224e-01,
#         -5.09292146e-01, -3.07098204e-01, -7.87002186e-01,
#          1.53275292e+00],
#        [ 2.75098810e-01,  2.98863300e-01,  0.00000000e+00,
#          0.00000000e+00,  1.38197902e-01,  1.18522654e+00,
#         -1.09958425e-01, -4.62095966e-01,  9.36832915e-02,
#         -5.16377335e-01,  1.60225829e-01,  2.35800488e-01,
#          2.41440214e-01, -3.07098204e-01,  2.36736538e-01,
#          3.12020186e-01],
#        [ 8.15199217e-02, -3.12105130e-01,  0.00000000e+00,
#          0.00000000e+00,  1.90738550e+00, -2.28819392e-01,
#         -6.64354121e-01,  1.23209786e+00, -9.35611465e-01,
#          2.25038365e-01, -6.74967476e-01, -7.52213881e-01,
#         -6.42097599e-01,  2.01131531e+00, -2.52844176e-01,
#         -6.64136739e-01],
# ...

# %%
x.skew()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2872/3673655344.py in <module>
# ----> 1 x.skew()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'skew'

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.38207890e+00,  9.62543504e-01,  0.00000000e+00,
#          0.00000000e+00,  1.68518793e+00,  1.00615029e+00,
#         -7.41927000e-01, -1.60519802e+00, -2.55061247e+00,
#          9.36131648e-01, -6.60978697e-01, -5.08052224e-01,
#         -5.09292146e-01, -3.07098204e-01, -7.87002186e-01,
#          1.53275292e+00],
#        [ 2.75098810e-01,  2.98863300e-01,  0.00000000e+00,
#          0.00000000e+00,  1.38197902e-01,  1.18522654e+00,
#         -1.09958425e-01, -4.62095966e-01,  9.36832915e-02,
#         -5.16377335e-01,  1.60225829e-01,  2.35800488e-01,
#          2.41440214e-01, -3.07098204e-01,  2.36736538e-01,
#          3.12020186e-01],
#        [ 8.15199217e-02, -3.12105130e-01,  0.00000000e+00,
#          0.00000000e+00,  1.90738550e+00, -2.28819392e-01,
#         -6.64354121e-01,  1.23209786e+00, -9.35611465e-01,
#          2.25038365e-01, -6.74967476e-01, -7.52213881e-01,
#         -6.42097599e-01,  2.01131531e+00, -2.52844176e-01,
#         -6.64136739e-01],
# ...

# %% [markdown]
# # Lets train the data set

# %%
# Sacling the data using MIN MAX Scaler:

# %%
features=df.drop("R",axis=1)
target=df["R"]

# %%
from sklearn.preprocessing import MinMaxScaler
mns=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"At random state{i},the training accuracy is :- {r2_score(target_train,pred_train)}")
    print(f"At random state{i},the testing accuracy is :- {r2_score(target_test,pred_test)}")
    print("\n")
# Out:
# At random state0,the training accuracy is :- 0.9657718006493989
# At random state0,the testing accuracy is :- 0.6287662140694792
#
#
# At random state1,the training accuracy is :- 0.9736286477631799
# At random state1,the testing accuracy is :- -0.862191560635186
#
#
# At random state2,the training accuracy is :- 0.9727251593015294
# At random state2,the testing accuracy is :- -3.5765170320129185
#
#
# At random state3,the training accuracy is :- 0.9676169062329719
# At random state3,the testing accuracy is :- 0.822792433893546
#
#
# At random state4,the training accuracy is :- 0.9828320289226363
# At random state4,the testing accuracy is :- -0.10168040158220104
#
#
# At random state5,the training accuracy is :- 0.9628228751835353
# At random state5,the testing accuracy is :- 0.7124498539358193
#
#
# At random state6,the training accuracy is :- 0.9708135921402112
# At random state6,the testing accuracy is :- 0.26178949286648234
#
#
# ...

# %% [markdown]
# # So we have seen training accuracy is higher than testing accuracy ....so the model is overfitted

# %% [markdown]
# # CV of the model

# %%
Train_accuracy=r2_score(target_train,pred_train)
Test_accuracy=r2_score(target_test,pred_test)
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"at cross fold{j} the cross score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy score for testing{Test_accuracy}")
    print("\n")
# Out:
# at cross fold2 the cross score is -0.7785945039373372 and accuracy score for training is 0.9597059524656956 and accuracy score for testing0.8380171544191897
#
#
# at cross fold3 the cross score is -1.2507041983543037 and accuracy score for training is 0.9597059524656956 and accuracy score for testing0.8380171544191897
#
#
# at cross fold4 the cross score is 0.717719825803712 and accuracy score for training is 0.9597059524656956 and accuracy score for testing0.8380171544191897
#
#
# at cross fold5 the cross score is 0.44908515501714386 and accuracy score for training is 0.9597059524656956 and accuracy score for testing0.8380171544191897
#
#
# at cross fold6 the cross score is 0.33471219726874274 and accuracy score for training is 0.9597059524656956 and accuracy score for testing0.8380171544191897
#
#
# at cross fold7 the cross score is 0.20579093738130996 and accuracy score for training is 0.9597059524656956 and accuracy score for testing0.8380171544191897
#
#
# ...

# %% [markdown]
# # HYPERTUNING

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # L1

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[0.0001,0.001,0.01,0.1,10],'random_state':list(range(0,10))}

# %%
ls=Lasso()
clif=GridSearchCV(ls,parameters)
clif.fit(features_train,target_train)
print(clif.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(features_train,target_train)
ls.score(features_train,target_train)
pred_ls=ls.predict(features_test)
lss=r2_score(target_test,pred_ls)
lss
# Out:
# 0.858577122016093

# %%
cv_score=cross_val_score(ls,features,target,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.46249597775179074

# %%
from sklearn.linear_model import Ridge
parameters={'alpha':[0.0001,0.001,0.01,0.1,10],'random_state':list(range(0,10))}

# %% [markdown]
# # L2

# %%
rd=Ridge()
clif=GridSearchCV(rd,parameters)
clif.fit(features_train,target_train)
print(clif.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
rd=Ridge(alpha=1,random_state=0)
rd.fit(features_train,target_train)
rd.score(features_train,target_train)
pred_rd=ls.predict(features_test)
rdd=r2_score(target_test,pred_ls)
rdd
# Out:
# 0.858577122016093

# %%
cv_score=cross_val_score(ls,features,target,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.46249597775179074

# %% [markdown]
# # Ensamble method

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
estimator = RandomForestRegressor()
parameters={'n_estimators': [300],
    'max_features': ['sqrt','log2'],
    'max_depth' : [3,4,5,6,7],
    'random_state' : [18]}
rf=RandomForestRegressor
clf=GridSearchCV(estimator, parameters, n_jobs=-1, cv=5)
clf.fit(features_train,target_train)
print(clf.best_params_)
# Out:
# {'max_depth': 4, 'max_features': 'sqrt', 'n_estimators': 300, 'random_state': 18}

# %%
rf=RandomForestRegressor(criterion="mse",max_features="auto")
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
pred_decision=rf.predict(features_test)
rfs=r2_score(target_test,pred_decision)
print("R2 score:",rfs*100)
rfscore=cross_val_score(rf,features,target,cv=5)
rfc=rfscore.mean()
print("Cross_val_score:",rfc*100)
# Out:
# R2 score: 15.159751249138587
# Cross_val_score: -57.70636030036671

# %%
import pickle
filename='game.pkl'
pickle.dump(rf,open(filename,'wb'))

# %% [markdown]
# # Conclution:

# %%
loaded_model=pickle.load(open('game.pkl','rb'))
results=loaded_model.score(features_test,target_test)

# %%
results
# Out:
# 0.15159751249138587

# %%
conclusion=pd.DataFrame([loaded_model.predict(features_test)[:],pred_decision[:]],index=['Predicted','Orginal'])
conclusion
# Out:
#                0       1       2       3       4       5
# Predicted  680.8  654.92  704.92  680.94  702.86  705.39
# Orginal    680.8  654.92  704.92  680.94  702.86  705.39
